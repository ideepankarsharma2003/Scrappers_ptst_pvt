# %%
from bs4 import BeautifulSoup

# %%
with open("ben 10.html") as f:
    html= f.read()

# %%
soup= BeautifulSoup(markup=html)

# %%
print(soup.prettify())
# Out:
# <div class="Yl- MIw Hb7" data-grid-item="true" role="listitem" style="top: 0px; left: 0px; transform: translateX(8px) translateY(0px); width: 236px; height: 473px;">
#  <div class="zI7 iyn Hsu">
#   <div class="XiG zI7 iyn Hsu zmN" data-test-id="pin" data-test-pin-id="621074604877054005">
#    <div class="lnZ wsz zI7 iyn Hsu zmN" data-test-id="pin-with-alt-text">
#     <div class="zI7 iyn Hsu" data-test-id="deeplink-wrapper">
#      <a aria-label="Imagens do Ben 10" class="Wk9 CCY S9z ho- kVc xQ4 iyn" href="/pin/621074604877054005/" rel="">
#       <div class="PinCard__imageWrapper" style="position: relative;">
#        <div class="XiG ho- sLG zI7 iyn Hsu" data-test-id="pincard-image-with-link" style="will-change: transform; text-decoration: none;">
#         <div class="XiG zI7 iyn Hsu" data-test-id="pin-visual-wrapper" style="margin-top: 0%; margin-bottom: 0%;">
#          <div class="Pj7 sLG XiG ho- m1e">
# ...

# %%
print(soup.find_all("a")[0].prettify())
# Out:
# <a aria-label="Imagens do Ben 10" class="Wk9 CCY S9z ho- kVc xQ4 iyn" href="/pin/621074604877054005/" rel="">
#  <div class="PinCard__imageWrapper" style="position: relative;">
#   <div class="XiG ho- sLG zI7 iyn Hsu" data-test-id="pincard-image-with-link" style="will-change: transform; text-decoration: none;">
#    <div class="XiG zI7 iyn Hsu" data-test-id="pin-visual-wrapper" style="margin-top: 0%; margin-bottom: 0%;">
#     <div class="Pj7 sLG XiG ho- m1e">
#      <div class="XiG zI7 iyn Hsu" style="background-color: rgb(255, 255, 254); padding-bottom: 186.017%;">
#       <img alt="Imagens do Ben 10" class="hCL kVc L4E MIw" fetchpriority="auto" loading="auto" src="https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg"/>
#      </div>
#      <div class="KPc MIw ojN Rym p6V QLY">
#      </div>
#     </div>
#    </div>
#   </div>
#  </div>
# </a>

# %%
top_n_anchors= soup.find_all("a")[::2] # because the anchors are in image and labels both, use only one
top_n_anchors
# Out:
# [<a aria-label="Imagens do Ben 10" class="Wk9 CCY S9z ho- kVc xQ4 iyn" href="/pin/621074604877054005/" rel="">
#  <div class="PinCard__imageWrapper" style="position: relative;">
#  <div class="XiG ho- sLG zI7 iyn Hsu" data-test-id="pincard-image-with-link" style="will-change: transform; text-decoration: none;">
#  <div class="XiG zI7 iyn Hsu" data-test-id="pin-visual-wrapper" style="margin-top: 0%; margin-bottom: 0%;">
#  <div class="Pj7 sLG XiG ho- m1e">
#  <div class="XiG zI7 iyn Hsu" style="background-color: rgb(255, 255, 254); padding-bottom: 186.017%;"><img alt="Imagens do Ben 10" class="hCL kVc L4E MIw" fetchpriority="auto" loading="auto" src="https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg"/>
#  </div>
#  <div class="KPc MIw ojN Rym p6V QLY"></div>
#  </div>
#  </div>
#  </div>
#  </div>
#  </a>,
#  <a aria-label="Ben 10 Cartoon 1080p PNG - Free Download" class="Wk9 CCY S9z ho- kVc xQ4 iyn" href="/pin/607282331032854714/" rel="">
# ...

# %%
import os

for anchor in top_n_anchors:
    img_file= anchor.find("img")
    if img_file:
        img_file= img_file.get("src", "none")
        
    base_file= os.path.basename(img_file)
    
    link= f"https://pinterest.com{anchor['href']}"
    print(link, img_file)
# Out:
# https://pinterest.com/pin/621074604877054005/ https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg
# https://pinterest.com/pin/607282331032854714/ https://i.pinimg.com/236x/1c/ee/d1/1ceed173d4e5b1bbe2cf2ffd3216dd44.jpg
# https://pinterest.com/pin/10907224090114754/ https://i.pinimg.com/236x/67/16/83/671683c300203133bbe95b12f2c4f9aa.jpg
# https://pinterest.com/pin/637118678548161823/ https://i.pinimg.com/236x/f0/f2/31/f0f231975af08d1bef9becabe604e19d.jpg
# https://pinterest.com/pin/9992430416477330/ https://i.pinimg.com/236x/38/d1/b0/38d1b0390cbbfb157e25aa4b3d66ece2.jpg
# https://pinterest.com/pin/1337074884425305/ https://i.pinimg.com/236x/fe/e6/16/fee61652aeaa7a14fd3cc8edd7a04e03.jpg
# https://pinterest.com/pin/190277152997417174/ https://i.pinimg.com/236x/72/19/50/72195035fe31047b117c14a558c18128.jpg
# https://pinterest.com/pin/19140367160685149/ https://i.pinimg.com/236x/8a/f4/52/8af45205d34223f47b51f14edffce4e5.jpg
# ...

# %%
import requests
soup_internal= BeautifulSoup(requests.get("https://pinterest.com/pin/621074604877054005/").content)
base_file= "a53bfc7fd39fc7c13981a98c53959313.jpg"
all_imgs= soup_internal.find_all("img")

alt_internal= ""
for img in all_imgs:
    src= img.get("src", "none")
    if os.path.basename(src)==base_file:
        print(img.get("alt", None))
# print(soup_internal.prettify())
# Out:
# an anime character with green and black hair pointing his finger at something in the air

# %%
def get_internal_alt_text(
    pinterest_page: str,
    base_file: str
):
    alt_internal= None
    try:
        soup_internal= BeautifulSoup(requests.get(pinterest_page).content)
        all_imgs= soup_internal.find_all("img")
        for img in all_imgs:
            src= img.get("src", "none")
            if os.path.basename(src)==base_file:
                alt_internal= img.get("alt", None)
                break
    except Exception as e:
        print(e)
    finally:
        return alt_internal

# %%
for anchor in top_n_anchors[:2]:
    img_file= anchor.find("img")
    if img_file:
        img_file= img_file.get("src", "none")
        
    base_file= os.path.basename(img_file)
    
    link= f"https://pinterest.com{anchor['href']}"
    alt= get_internal_alt_text(link, base_file)
    print((alt, link, img_file))
# Out:
# ('an anime character with green and black hair pointing his finger at something in the air', 'https://pinterest.com/pin/621074604877054005/', 'https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg')
# ('a cartoon character with green eyes and brown hair, holding his arms crossed in front of him', 'https://pinterest.com/pin/607282331032854714/', 'https://i.pinimg.com/236x/1c/ee/d1/1ceed173d4e5b1bbe2cf2ffd3216dd44.jpg')

# %%
top_n_images= soup.find_all("img")[:10]
top_n_images
# Out:
# [<img alt="Imagens do Ben 10" class="hCL kVc L4E MIw" fetchpriority="auto" loading="auto" src="https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg"/>,
#  <img alt="Ben 10 Cartoon 1080p PNG - Free Download" class="hCL kVc L4E MIw" fetchpriority="auto" loading="auto" src="https://i.pinimg.com/236x/1c/ee/d1/1ceed173d4e5b1bbe2cf2ffd3216dd44.jpg"/>,
#  <img alt="Alien X" class="hCL kVc L4E MIw" fetchpriority="auto" loading="auto" src="https://i.pinimg.com/236x/67/16/83/671683c300203133bbe95b12f2c4f9aa.jpg"/>,
#  <img alt="Ben 10 (2016)" class="hCL kVc L4E MIw" fetchpriority="auto" loading="auto" src="https://i.pinimg.com/236x/f0/f2/31/f0f231975af08d1bef9becabe604e19d.jpg"/>,
#  <img alt="Green colour and Black Colour" class="hCL kVc L4E MIw" fetchpriority="auto" loading="auto" src="https://i.pinimg.com/236x/38/d1/b0/38d1b0390cbbfb157e25aa4b3d66ece2.jpg"/>,
# ...

# %%
top_n_images[0].get("alt", "None")
# Out:
# 'Imagens do Ben 10'

# %%
image_sources= []
image_alt_texts= []

for img in top_n_images:
    alt= img.get("alt", "None")
    src= img.get("src", "None")
    image_sources.append(src)
    image_alt_texts.append(alt)
    
    
image_sources, image_alt_texts
# Out:
# (['https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg',
#   'https://i.pinimg.com/236x/1c/ee/d1/1ceed173d4e5b1bbe2cf2ffd3216dd44.jpg',
#   'https://i.pinimg.com/236x/67/16/83/671683c300203133bbe95b12f2c4f9aa.jpg',
#   'https://i.pinimg.com/236x/f0/f2/31/f0f231975af08d1bef9becabe604e19d.jpg',
#   'https://i.pinimg.com/236x/38/d1/b0/38d1b0390cbbfb157e25aa4b3d66ece2.jpg',
#   'https://i.pinimg.com/236x/fe/e6/16/fee61652aeaa7a14fd3cc8edd7a04e03.jpg',
#   'https://i.pinimg.com/236x/72/19/50/72195035fe31047b117c14a558c18128.jpg',
#   'https://i.pinimg.com/236x/8a/f4/52/8af45205d34223f47b51f14edffce4e5.jpg',
#   'https://i.pinimg.com/236x/ad/f2/e4/adf2e43db14bf8ea23a0ab99ba2a4ad0.jpg',
#   'https://i.pinimg.com/236x/34/58/29/345829a8daa2137661f18242ac113748.jpg'],
#  ['Imagens do Ben 10',
#   'Ben 10 Cartoon 1080p PNG - Free Download',
#   'Alien X',
#   'Ben 10 (2016)',
#   'Green colour and Black Colour',
# ...

# %%
for i in zip(image_sources, image_alt_texts):
    print(i)
# Out:
# ('https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg', 'Imagens do Ben 10')
# ('https://i.pinimg.com/236x/1c/ee/d1/1ceed173d4e5b1bbe2cf2ffd3216dd44.jpg', 'Ben 10 Cartoon 1080p PNG - Free Download')
# ('https://i.pinimg.com/236x/67/16/83/671683c300203133bbe95b12f2c4f9aa.jpg', 'Alien X')
# ('https://i.pinimg.com/236x/f0/f2/31/f0f231975af08d1bef9becabe604e19d.jpg', 'Ben 10 (2016)')
# ('https://i.pinimg.com/236x/38/d1/b0/38d1b0390cbbfb157e25aa4b3d66ece2.jpg', 'Green colour and Black Colour')
# ('https://i.pinimg.com/236x/fe/e6/16/fee61652aeaa7a14fd3cc8edd7a04e03.jpg', 'Ben 10 ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼ ï¿¼')
# ('https://i.pinimg.com/236x/72/19/50/72195035fe31047b117c14a558c18128.jpg', 'Ben 10 wallpaper')
# ...

# %% [markdown]
# ```bash
# curl -X 'POST' \
#   'http://35.172.203.13:8501/uploadfile' \
#   -H 'accept: application/json' \
#   -H 'Content-Type: multipart/form-data' \
#   -F 'file=@Peru.jpg;type=image/jpeg' \
#   -F 'conditional_text=' \
#   -F 'keyword_str='
# ```

# %%
import json
import requests
headers = {"Authorization": f"Bearer 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"}
API_URL = "https://api-inference.huggingface.co/models/Salesforce/blip-image-captioning-large"
def query(filename):
    with open(filename, "rb") as f:
        data = f.read()
    response = requests.request("POST", API_URL, headers=headers, data=data)
    return json.loads(response.content.decode("utf-8"))


filename= "temp.jpeg"
with open(filename, "wb") as f:
    f.write(requests.get(url="https://i.pinimg.com/236x/fe/e6/16/fee61652aeaa7a14fd3cc8edd7a04e03.jpg").content)
    


data = query(filename)
data[0]['generated_text']
# Out:
# 'ben ben and the green lanterners'

# %%
from tqdm import tqdm

def get_img_src_and_alts(
    soup_content:str,
    n: int
):
    soup= BeautifulSoup(markup=soup_content)
    all_anchors= soup.find_all("a")[::2] # because the anchors are in image and labels both, use only one
    top_n_anchors= all_anchors[:n]
    # top_n_images= soup.find_all("img")[:n]
    image_sources= []
    image_original_alt_texts= []
    image_original_alt_texts_internal= []
    image_alt_texts= []

    for anchor in tqdm(top_n_anchors):
        img= anchor.find("img")        
        alt= img.get("alt", "None")
        src= img.get("src", "None")
        base_file= os.path.basename(src)
        
        link= f"https://pinterest.com{anchor['href']}"        
        main_alt= get_internal_alt_text(link, base_file)
        
        image_original_alt_texts_internal.append(main_alt)
        image_sources.append(src)
        image_original_alt_texts.append(alt)
        
        filename= "temp.jpeg"
        with open(filename, "wb") as f:
            f.write(requests.get(url=src).content)
        alt_text= query(filename)[0]['generated_text']
        image_alt_texts.append(alt_text)
        

        
        
    return zip(image_alt_texts, image_original_alt_texts_internal, image_original_alt_texts, image_sources)

# %%
object= get_img_src_and_alts(html,3)
for i in object:
    print(i)
# Out:
# ...
# 100%|██████████| 3/3 [00:14<00:00,  4.70s/it]
# ('ben the green lanterner', 'an anime character with green and black hair pointing his finger at something in the air', 'Imagens do Ben 10', 'https://i.pinimg.com/236x/a5/3b/fc/a53bfc7fd39fc7c13981a98c53959313.jpg')
# ('a cartoon boy in a tie and green pants holding a camera', 'a cartoon character with green eyes and brown hair, holding his arms crossed in front of him', 'Ben 10 Cartoon 1080p PNG - Free Download', 'https://i.pinimg.com/236x/1c/ee/d1/1ceed173d4e5b1bbe2cf2ffd3216dd44.jpg')
# ('a man in a green suit stands in front of a black background', 'a man standing in the middle of a triangle with green light on his face and chest', 'Alien X', 'https://i.pinimg.com/236x/67/16/83/671683c300203133bbe95b12f2c4f9aa.jpg')
